# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# standard imports
import tensorrt #For GPU
from tensorflow import keras
import numpy as np
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras import layers
import random
from sklearn import preprocessing
from keras.callbacks import History
import matplotlib.pyplot as plt
import np_utils
import os
from tensorflow.keras.optimizers import Adam
from plain_neural_network import*
from keras import backend as K

# %matplotlib inline
# Out:
# 2023-11-01 17:30:16.264752: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5014211832794196988
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 45610434560
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#   }
# }
# incarnation: 5962875006907881268
# physical_device_desc: "device: 0, name: NVIDIA A40, pci bus id: 0000:41:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2023-11-01 17:30:51.526447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:0 with 43497 MB memory:  -> device: 0, name: NVIDIA A40, pci bus id: 0000:41:00.0, compute capability: 8.6

# %%
import glob
input_dir = "/albedo/work/user/ssunar/for_paper/segmentation_masks/Gulfstream/"
input_file_paths = sorted(glob.glob(input_dir+'*.nc'))
# The first file throws an error when we do xr.open_mfdataset
data = xr.open_mfdataset(input_file_paths,combine = 'nested', concat_dim="TIME").astype('float32')
X = data.ssh.to_numpy()
Y = data.seg_mask.to_numpy()
X[X>1000] = 0

X.shape
Y.shape
# Out:
# '/albedo/work/user/ssunar/for_paper/segmentation_masks/Gulfstream/seg_mask_gridded_2009_001_02_new.nc'
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
# ...
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitGroomNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeGranularBitRoundNumberOfSignificantDigits'
#     major: Attribute
#     minor: Object not found
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 1:
#   #000: H5A.c line 528 in H5Aopen_by_name(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #001: H5VLcallback.c line 1091 in H5VL_attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #002: H5VLcallback.c line 1058 in H5VL__attr_open(): attribute open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLnative_attr.c line 130 in H5VL__native_attr_open(): can't open attribute
#     major: Attribute
#     minor: Can't open object
#   #004: H5Aint.c line 545 in H5A__open_by_name(): unable to load attribute info from object header
#     major: Attribute
#     minor: Unable to initialize object
#   #005: H5Oattribute.c line 494 in H5O__attr_open_by_name(): can't locate attribute: '_QuantizeBitRoundNumberOfSignificantBits'
#     major: Attribute
#     minor: Object not found
# (3958, 600, 300)
# (3958, 600, 300)

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:    (TIME: 3958, LONGITUDE: 600, LATITUDE: 300)
# Coordinates:
#   * LONGITUDE  (LONGITUDE) float32 -60.0 -59.92 -59.83 ... -10.25 -10.17 -10.08
#   * LATITUDE   (LATITUDE) float32 30.0 30.08 30.17 30.25 ... 54.75 54.83 54.92
#   * TIME       (TIME) float32 5.186e+05 5.187e+05 ... 6.136e+05 6.136e+05
# Data variables:
#     ssh        (TIME, LONGITUDE, LATITUDE) float32 dask.array<chunksize=(31, 600, 300), meta=np.ndarray>
#     seg_mask   (TIME, LONGITUDE, LATITUDE) float32 dask.array<chunksize=(31, 600, 300), meta=np.ndarray>

# %%
data_long = data.LONGITUDE
data_lat = data.LATITUDE
xx, yy = np.meshgrid(data_long, data_lat)

# %%
from matplotlib import cm
fig, ax = plt.subplots( 1, 1, )
ax.pcolormesh(data_long,data_lat,np.transpose(X[100,:,:]), cmap=cm.seismic, vmin=-1, vmax=1)
ax.contour(xx, yy, np.transpose(Y[100,:,:]), levels=[0,1])
# Out:
# /tmp/ipykernel_474212/3071145902.py:3: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(data_long,data_lat,np.transpose(X[100,:,:]), cmap=cm.seismic, vmin=-1, vmax=1)

# %%
Y[(Y != 1) & (Y!=2)] = 0

# %%
def split_3d_vector(vector):
    X, Y, Z = vector.shape
    chunks = []
    
    for i in range(X):
        vector_2d = vector[i,:,:]
        B = Y // 256 + 1
        for b in range(B):
            start_y = b * 256
            end_y = (b + 1) * 256
            if end_y > Y:
                start_y = Y - 256
                end_y = Y
      
            C = Z // 256 + 1
            for c in range(C):
                start_z = c * 256
                end_z = (c + 1) * 256
                if end_z > Z:
                    start_z = Z - 256
                    end_z = Z
                final_chunk = vector_2d[start_y:end_y, start_z:end_z]
                chunks.append(final_chunk)
    return chunks

# %%
new_X = np.array(split_3d_vector(X))
new_Y = np.array(split_3d_vector(Y))

data_x = new_X
data_y = new_Y

(data_x.shape)
(data_y.shape)
# Out:
# (23748, 256, 256)
# (23748, 256, 256)

# %%
img_size = (256, 256)
num_classes = 3
batch_size = 16
epochs = 60
total_samples = len(data_x)-1000
# if len(data_x) > 4000:
#     total_samples = 4000
# else:
#     total_samples = len(data_x)
print(total_samples)
# Out:
# 22748

# %%
model = get_model(img_size, num_classes)
model.summary()
# Out:
# 2023-11-01 17:52:57.501609: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43497 MB memory:  -> device: 0, name: NVIDIA A40, pci bus id: 0000:41:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 1)]        0         []
#
#  separable_conv2d (Separabl  (None, 256, 256, 8)          17        ['input_1[0][0]']
#  eConv2D)
#
#  batch_normalization (Batch  (None, 256, 256, 8)          32        ['separable_conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 256, 256, 8)          0         ['batch_normalization[0][0]']
#
#  separable_conv2d_1 (Separa  (None, 256, 256, 8)          136       ['activation[0][0]']
#  bleConv2D)
#
#  batch_normalization_1 (Bat  (None, 256, 256, 8)          32        ['separable_conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256, 256, 8)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 256, 256, 8)          0         ['activation_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 8)          0         ['dropout[0][0]']
#  D)
#
#  separable_conv2d_2 (Separa  (None, 128, 128, 16)         200       ['max_pooling2d[0][0]']
#  bleConv2D)
#
#  batch_normalization_2 (Bat  (None, 128, 128, 16)         64        ['separable_conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 128, 128, 16)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  separable_conv2d_3 (Separa  (None, 128, 128, 16)         400       ['activation_2[0][0]']
#  bleConv2D)
#
#  batch_normalization_3 (Bat  (None, 128, 128, 16)         64        ['separable_conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 16)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 128, 128, 16)         0         ['activation_3[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 16)           0         ['dropout_1[0][0]']
#  g2D)
#
#  separable_conv2d_4 (Separa  (None, 64, 64, 16)           400       ['max_pooling2d_1[0][0]']
#  bleConv2D)
#
#  batch_normalization_4 (Bat  (None, 64, 64, 16)           64        ['separable_conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 64, 64, 16)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  separable_conv2d_5 (Separa  (None, 64, 64, 16)           400       ['activation_4[0][0]']
#  bleConv2D)
#
#  batch_normalization_5 (Bat  (None, 64, 64, 16)           64        ['separable_conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64, 64, 16)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 64, 64, 16)           0         ['activation_5[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 16)           0         ['dropout_2[0][0]']
#  g2D)
#
#  separable_conv2d_6 (Separa  (None, 32, 32, 32)           656       ['max_pooling2d_2[0][0]']
#  bleConv2D)
#
#  batch_normalization_6 (Bat  (None, 32, 32, 32)           128       ['separable_conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32, 32, 32)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  separable_conv2d_7 (Separa  (None, 32, 32, 32)           1312      ['activation_6[0][0]']
#  bleConv2D)
#
#  batch_normalization_7 (Bat  (None, 32, 32, 32)           128       ['separable_conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 32)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 32, 32, 32)           0         ['activation_7[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 64, 64, 32)           0         ['dropout_3[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 64, 64, 48)           0         ['up_sampling2d[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  separable_conv2d_8 (Separa  (None, 64, 64, 16)           1200      ['concatenate[0][0]']
#  bleConv2D)
#
#  batch_normalization_8 (Bat  (None, 64, 64, 16)           64        ['separable_conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 64, 64, 16)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  separable_conv2d_9 (Separa  (None, 64, 64, 16)           400       ['activation_8[0][0]']
#  bleConv2D)
#
#  batch_normalization_9 (Bat  (None, 64, 64, 16)           64        ['separable_conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 64, 64, 16)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 64, 64, 16)           0         ['activation_9[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 128, 128, 16)         0         ['dropout_4[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 128, 128, 32)         0         ['up_sampling2d_1[0][0]',
#  )                                                                   'dropout_1[0][0]']
#
#  separable_conv2d_10 (Separ  (None, 128, 128, 16)         800       ['concatenate_1[0][0]']
#  ableConv2D)
#
#  batch_normalization_10 (Ba  (None, 128, 128, 16)         64        ['separable_conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 128, 128, 16)         0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  separable_conv2d_11 (Separ  (None, 128, 128, 16)         400       ['activation_10[0][0]']
#  ableConv2D)
#
#  batch_normalization_11 (Ba  (None, 128, 128, 16)         64        ['separable_conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 128, 128, 16)         0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  dropout_5 (Dropout)         (None, 128, 128, 16)         0         ['activation_11[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 256, 256, 16)         0         ['dropout_5[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 256, 256, 24)         0         ['up_sampling2d_2[0][0]',
#  )                                                                   'dropout[0][0]']
#
#  separable_conv2d_12 (Separ  (None, 256, 256, 8)          408       ['concatenate_2[0][0]']
#  ableConv2D)
#
#  batch_normalization_12 (Ba  (None, 256, 256, 8)          32        ['separable_conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 256, 256, 8)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  separable_conv2d_13 (Separ  (None, 256, 256, 8)          136       ['activation_12[0][0]']
#  ableConv2D)
#
#  batch_normalization_13 (Ba  (None, 256, 256, 8)          32        ['separable_conv2d_13[0][0]']
#  tchNormalization)
#  activation_13 (Activation)  (None, 256, 256, 8)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 256, 256, 8)          0         ['activation_13[0][0]']
#
#  separable_conv2d_14 (Separ  (None, 256, 256, 3)          32        ['dropout_6[0][0]']
#  ableConv2D)
#
#  reshape (Reshape)           (None, 65536, 3)             0         ['separable_conv2d_14[0][0]']
#
#  activation_14 (Activation)  (None, 65536, 3)             0         ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 7793 (30.44 KB)
# Trainable params: 7345 (28.69 KB)
# Non-trainable params: 448 (1.75 KB)
# __________________________________________________________________________________________________

# %%
#Loss function 
#defined from the paper:
#Santana et al._2020_Neural network training for the detection and classification of oceanic mesoscale eddies

unique, counts = np.unique(data_y, return_counts=True)
dict(zip(unique, counts))

freq = [np.sum(counts)/j for j in counts]
weightsSeg = [f/np.sum(freq) for f in freq]
print(weightsSeg)

def dice_coef_anti(y_true, y_pred):
    smooth = 1.  # to avoid zero division
    y_true_anti = y_true[:,:,1]
    y_pred_anti = y_pred[:,:,1]
    intersection_anti = K.sum(y_true_anti * y_pred_anti)
    return (2 * intersection_anti + smooth) / (K.sum(y_true_anti)+ K.sum(y_pred_anti) + smooth)

def dice_coef_cyc(y_true, y_pred):
    smooth = 1.  # to avoid zero division
    y_true_cyc = y_true[:,:,2]
    y_pred_cyc = y_pred[:,:,2]
    intersection_cyc = K.sum(y_true_cyc * y_pred_cyc)
    return (2 * intersection_cyc + smooth) / (K.sum(y_true_cyc) + K.sum(y_pred_cyc) + smooth)

def dice_coef_nn(y_true, y_pred):
    smooth = 1.  # to avoid zero division
    y_true_nn = y_true[:,:,0]
    y_pred_nn = y_pred[:,:,0]
    intersection_nn = K.sum(y_true_nn * y_pred_nn)
    return (2 * intersection_nn + smooth) / (K.sum(y_true_nn) + K.sum(y_pred_nn) + smooth)
    
def mean_dice_coef(y_true, y_pred):
    return (dice_coef_anti(y_true, y_pred) + dice_coef_cyc(y_true, y_pred) + dice_coef_nn(y_true, y_pred))/3.

def weighted_mean_dice_coef(y_true, y_pred):
    #return (weightsSeg[2]*dice_coef_anti(y_true, y_pred) + weightsSeg[1]*dice_coef_cyc(y_true, y_pred) + weightsSeg[0]*dice_coef_nn(y_true, y_pred))
    return (weightsSeg[2]*dice_coef_anti(y_true, y_pred) + weightsSeg[1]*dice_coef_cyc(y_true, y_pred) + weightsSeg[0]*dice_coef_nn(y_true, y_pred))
      
def dice_coef_loss(y_true, y_pred):
    return 1 - weighted_mean_dice_coef(y_true, y_pred)
# Out:
# {0.0: 1309064530, 1.0: 136390594, 2.0: 110893804}
# [0.04463772168534579, 0.4284287973575216, 0.5269334809571325]

# %%
# Split our img paths into a training and a validation set
split = 0.3
train_samples = int((1-split)*total_samples)
#same seed must be used
random.Random(0).shuffle(data_x)
random.Random(0).shuffle(data_y)
train_input = data_x[0:train_samples]
train_target = data_y[0:train_samples]
val_input = data_x[train_samples:total_samples]
val_target = data_y[train_samples:total_samples]

print("train_input:", train_input.shape)
print("val_input:", val_input.shape)

# Instantiate data Sequences for each split
train_gen = plain_net_eddy(batch_size, img_size, train_input, train_target)
val_gen = plain_net_eddy(batch_size, img_size, val_input, val_target)
print("Size of each batch: ",train_gen[1][0].shape)
# Out:
# train_input: (15923, 256, 256)
# val_input: (6825, 256, 256)
# Size of each batch:  (16, 256, 256, 1)

# %%
os.environ['XLA_FLAGS'] = '--xla_gpu_cuda_data_dir=/albedo/soft/sw/spack-sw/cuda/11.7.0-qk7q7bh/'
os.environ['XLA_FLAGS']
# print(os.environ.get('CUDA_HOME'))
# Out:
# '--xla_gpu_cuda_data_dir=/albedo/soft/sw/spack-sw/cuda/11.7.0-qk7q7bh/'

# %%
file_path_save = "/albedo/work/user/ssunar/for_paper/unet_trained/Gulfstream/train"
os.makedirs(file_path_save, exist_ok=True)
model.compile(optimizer=Adam(lr=1e-3), loss=dice_coef_loss, metrics=['categorical_accuracy', mean_dice_coef, weighted_mean_dice_coef])

callbacks = [keras.callbacks.ModelCheckpoint(file_path_save, save_best_only=True , monitor='val_loss',save_weights_only=True, save_freq="epoch"),
            keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1, mode='auto', min_delta=1e-30, min_lr=1e-30)]

# Train the model, doing validation at the end of each epoch.
history = model.fit(train_gen, epochs=epochs, validation_data=val_gen, callbacks=callbacks, shuffle=True,verbose=1)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/60
# 2023-11-01 17:54:44.235016: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-01 17:54:55.558090: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8904
# 2023-11-01 17:55:12.395571: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-01 17:55:15.381544: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x15511634de40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-01 17:55:15.381596: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A40, Compute Capability 8.6
# 2023-11-01 17:55:17.188472: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-01 17:55:19.757383: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 995/995 [==============================] - 150s 103ms/step - loss: 0.5711 - categorical_accuracy: 0.7649 - mean_dice_coef: 0.5410 - weighted_mean_dice_coef: 0.4289 - val_loss: 0.4570 - val_categorical_accuracy: 0.8689 - val_mean_dice_coef: 0.6592 - val_weighted_mean_dice_coef: 0.5430 - lr: 0.0010
# Epoch 2/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.4366 - categorical_accuracy: 0.8794 - mean_dice_coef: 0.6723 - weighted_mean_dice_coef: 0.5634 - val_loss: 0.4197 - val_categorical_accuracy: 0.8803 - val_mean_dice_coef: 0.6855 - val_weighted_mean_dice_coef: 0.5803 - lr: 0.0010
# Epoch 3/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.4161 - categorical_accuracy: 0.8869 - mean_dice_coef: 0.6879 - weighted_mean_dice_coef: 0.5839 - val_loss: 0.4499 - val_categorical_accuracy: 0.8826 - val_mean_dice_coef: 0.6670 - val_weighted_mean_dice_coef: 0.5501 - lr: 0.0010
# Epoch 4/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.4053 - categorical_accuracy: 0.8899 - mean_dice_coef: 0.6960 - weighted_mean_dice_coef: 0.5947 - val_loss: 0.3905 - val_categorical_accuracy: 0.8863 - val_mean_dice_coef: 0.7055 - val_weighted_mean_dice_coef: 0.6095 - lr: 0.0010
# Epoch 5/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3983 - categorical_accuracy: 0.8921 - mean_dice_coef: 0.7013 - weighted_mean_dice_coef: 0.6017 - val_loss: 0.3689 - val_categorical_accuracy: 0.8773 - val_mean_dice_coef: 0.7191 - val_weighted_mean_dice_coef: 0.6311 - lr: 0.0010
# Epoch 6/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3935 - categorical_accuracy: 0.8936 - mean_dice_coef: 0.7049 - weighted_mean_dice_coef: 0.6065 - val_loss: 0.4053 - val_categorical_accuracy: 0.8890 - val_mean_dice_coef: 0.6982 - val_weighted_mean_dice_coef: 0.5947 - lr: 0.0010
# Epoch 7/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3894 - categorical_accuracy: 0.8948 - mean_dice_coef: 0.7080 - weighted_mean_dice_coef: 0.6106 - val_loss: 0.3689 - val_categorical_accuracy: 0.8891 - val_mean_dice_coef: 0.7217 - val_weighted_mean_dice_coef: 0.6311 - lr: 0.0010
# Epoch 8/60
# 995/995 [==============================] - 101s 102ms/step - loss: 0.3862 - categorical_accuracy: 0.8958 - mean_dice_coef: 0.7104 - weighted_mean_dice_coef: 0.6138 - val_loss: 0.4744 - val_categorical_accuracy: 0.8854 - val_mean_dice_coef: 0.6508 - val_weighted_mean_dice_coef: 0.5256 - lr: 0.0010
# Epoch 9/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3834 - categorical_accuracy: 0.8966 - mean_dice_coef: 0.7125 - weighted_mean_dice_coef: 0.6167 - val_loss: 0.3534 - val_categorical_accuracy: 0.8898 - val_mean_dice_coef: 0.7323 - val_weighted_mean_dice_coef: 0.6466 - lr: 0.0010
# Epoch 10/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3800 - categorical_accuracy: 0.8977 - mean_dice_coef: 0.7151 - weighted_mean_dice_coef: 0.6200 - val_loss: 0.3570 - val_categorical_accuracy: 0.8921 - val_mean_dice_coef: 0.7304 - val_weighted_mean_dice_coef: 0.6430 - lr: 0.0010
# Epoch 11/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3778 - categorical_accuracy: 0.8984 - mean_dice_coef: 0.7168 - weighted_mean_dice_coef: 0.6222 - val_loss: 0.3469 - val_categorical_accuracy: 0.8917 - val_mean_dice_coef: 0.7370 - val_weighted_mean_dice_coef: 0.6531 - lr: 0.0010
# Epoch 12/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3762 - categorical_accuracy: 0.8988 - mean_dice_coef: 0.7180 - weighted_mean_dice_coef: 0.6238 - val_loss: 0.3908 - val_categorical_accuracy: 0.8838 - val_mean_dice_coef: 0.7081 - val_weighted_mean_dice_coef: 0.6092 - lr: 0.0010
# Epoch 13/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3747 - categorical_accuracy: 0.8993 - mean_dice_coef: 0.7191 - weighted_mean_dice_coef: 0.6253 - val_loss: 0.3444 - val_categorical_accuracy: 0.8898 - val_mean_dice_coef: 0.7384 - val_weighted_mean_dice_coef: 0.6556 - lr: 0.0010
# Epoch 14/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3729 - categorical_accuracy: 0.8999 - mean_dice_coef: 0.7205 - weighted_mean_dice_coef: 0.6271 - val_loss: 0.3426 - val_categorical_accuracy: 0.8939 - val_mean_dice_coef: 0.7409 - val_weighted_mean_dice_coef: 0.6574 - lr: 0.0010
# Epoch 15/60
# 995/995 [==============================] - 101s 102ms/step - loss: 0.3709 - categorical_accuracy: 0.9005 - mean_dice_coef: 0.7221 - weighted_mean_dice_coef: 0.6291 - val_loss: 0.3531 - val_categorical_accuracy: 0.8858 - val_mean_dice_coef: 0.7322 - val_weighted_mean_dice_coef: 0.6469 - lr: 0.0010
# Epoch 16/60
# 995/995 [==============================] - 101s 102ms/step - loss: 0.3692 - categorical_accuracy: 0.9014 - mean_dice_coef: 0.7234 - weighted_mean_dice_coef: 0.6308 - val_loss: 0.3870 - val_categorical_accuracy: 0.8900 - val_mean_dice_coef: 0.7117 - val_weighted_mean_dice_coef: 0.6130 - lr: 0.0010
# Epoch 17/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3683 - categorical_accuracy: 0.9017 - mean_dice_coef: 0.7241 - weighted_mean_dice_coef: 0.6317 - val_loss: 0.3498 - val_categorical_accuracy: 0.8914 - val_mean_dice_coef: 0.7356 - val_weighted_mean_dice_coef: 0.6502 - lr: 0.0010
# Epoch 18/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3669 - categorical_accuracy: 0.9020 - mean_dice_coef: 0.7251 - weighted_mean_dice_coef: 0.6331 - val_loss: 0.3411 - val_categorical_accuracy: 0.8848 - val_mean_dice_coef: 0.7397 - val_weighted_mean_dice_coef: 0.6589 - lr: 0.0010
# Epoch 19/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3656 - categorical_accuracy: 0.9024 - mean_dice_coef: 0.7262 - weighted_mean_dice_coef: 0.6344 - val_loss: 0.3538 - val_categorical_accuracy: 0.8821 - val_mean_dice_coef: 0.7306 - val_weighted_mean_dice_coef: 0.6462 - lr: 0.0010
# Epoch 20/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3644 - categorical_accuracy: 0.9027 - mean_dice_coef: 0.7270 - weighted_mean_dice_coef: 0.6356 - val_loss: 0.3535 - val_categorical_accuracy: 0.8938 - val_mean_dice_coef: 0.7331 - val_weighted_mean_dice_coef: 0.6465 - lr: 0.0010
# Epoch 21/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3639 - categorical_accuracy: 0.9030 - mean_dice_coef: 0.7274 - weighted_mean_dice_coef: 0.6361 - val_loss: 0.3312 - val_categorical_accuracy: 0.8942 - val_mean_dice_coef: 0.7486 - val_weighted_mean_dice_coef: 0.6688 - lr: 0.0010
# Epoch 22/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3631 - categorical_accuracy: 0.9032 - mean_dice_coef: 0.7280 - weighted_mean_dice_coef: 0.6369 - val_loss: 0.3432 - val_categorical_accuracy: 0.8930 - val_mean_dice_coef: 0.7402 - val_weighted_mean_dice_coef: 0.6568 - lr: 0.0010
# Epoch 23/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3625 - categorical_accuracy: 0.9033 - mean_dice_coef: 0.7284 - weighted_mean_dice_coef: 0.6375 - val_loss: 0.3321 - val_categorical_accuracy: 0.8903 - val_mean_dice_coef: 0.7474 - val_weighted_mean_dice_coef: 0.6679 - lr: 0.0010
# Epoch 24/60
# 995/995 [==============================] - 103s 104ms/step - loss: 0.3615 - categorical_accuracy: 0.9036 - mean_dice_coef: 0.7292 - weighted_mean_dice_coef: 0.6385 - val_loss: 0.3378 - val_categorical_accuracy: 0.8918 - val_mean_dice_coef: 0.7440 - val_weighted_mean_dice_coef: 0.6622 - lr: 0.0010
# Epoch 25/60
# 995/995 [==============================] - 100s 100ms/step - loss: 0.3605 - categorical_accuracy: 0.9036 - mean_dice_coef: 0.7298 - weighted_mean_dice_coef: 0.6395 - val_loss: 0.3395 - val_categorical_accuracy: 0.8867 - val_mean_dice_coef: 0.7415 - val_weighted_mean_dice_coef: 0.6605 - lr: 0.0010
# Epoch 26/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3593 - categorical_accuracy: 0.9039 - mean_dice_coef: 0.7307 - weighted_mean_dice_coef: 0.6407 - val_loss: 0.3583 - val_categorical_accuracy: 0.8876 - val_mean_dice_coef: 0.7305 - val_weighted_mean_dice_coef: 0.6417 - lr: 0.0010
# Epoch 27/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3593 - categorical_accuracy: 0.9040 - mean_dice_coef: 0.7308 - weighted_mean_dice_coef: 0.6407 - val_loss: 0.3363 - val_categorical_accuracy: 0.8906 - val_mean_dice_coef: 0.7450 - val_weighted_mean_dice_coef: 0.6637 - lr: 0.0010
# Epoch 28/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3587 - categorical_accuracy: 0.9042 - mean_dice_coef: 0.7312 - weighted_mean_dice_coef: 0.6413 - val_loss: 0.3374 - val_categorical_accuracy: 0.8957 - val_mean_dice_coef: 0.7447 - val_weighted_mean_dice_coef: 0.6626 - lr: 0.0010
# Epoch 29/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3577 - categorical_accuracy: 0.9044 - mean_dice_coef: 0.7320 - weighted_mean_dice_coef: 0.6423 - val_loss: 0.3239 - val_categorical_accuracy: 0.8860 - val_mean_dice_coef: 0.7517 - val_weighted_mean_dice_coef: 0.6761 - lr: 0.0010
# Epoch 30/60
# 995/995 [==============================] - 101s 102ms/step - loss: 0.3567 - categorical_accuracy: 0.9046 - mean_dice_coef: 0.7327 - weighted_mean_dice_coef: 0.6433 - val_loss: 0.3282 - val_categorical_accuracy: 0.8949 - val_mean_dice_coef: 0.7509 - val_weighted_mean_dice_coef: 0.6718 - lr: 0.0010
# Epoch 31/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3552 - categorical_accuracy: 0.9049 - mean_dice_coef: 0.7339 - weighted_mean_dice_coef: 0.6448 - val_loss: 0.3300 - val_categorical_accuracy: 0.8869 - val_mean_dice_coef: 0.7479 - val_weighted_mean_dice_coef: 0.6700 - lr: 0.0010
# Epoch 32/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3535 - categorical_accuracy: 0.9054 - mean_dice_coef: 0.7352 - weighted_mean_dice_coef: 0.6465 - val_loss: 0.3225 - val_categorical_accuracy: 0.8910 - val_mean_dice_coef: 0.7537 - val_weighted_mean_dice_coef: 0.6775 - lr: 0.0010
# Epoch 33/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3532 - categorical_accuracy: 0.9056 - mean_dice_coef: 0.7355 - weighted_mean_dice_coef: 0.6468 - val_loss: 0.3367 - val_categorical_accuracy: 0.8830 - val_mean_dice_coef: 0.7417 - val_weighted_mean_dice_coef: 0.6633 - lr: 0.0010
# Epoch 34/60
# 995/995 [==============================] - 103s 104ms/step - loss: 0.3526 - categorical_accuracy: 0.9055 - mean_dice_coef: 0.7359 - weighted_mean_dice_coef: 0.6474 - val_loss: 0.3248 - val_categorical_accuracy: 0.8912 - val_mean_dice_coef: 0.7523 - val_weighted_mean_dice_coef: 0.6752 - lr: 0.0010
# Epoch 35/60
# 995/995 [==============================] - 101s 101ms/step - loss: 0.3524 - categorical_accuracy: 0.9057 - mean_dice_coef: 0.7361 - weighted_mean_dice_coef: 0.6476 - val_loss: 0.3395 - val_categorical_accuracy: 0.8990 - val_mean_dice_coef: 0.7447 - val_weighted_mean_dice_coef: 0.6605 - lr: 0.0010
# Epoch 36/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3525 - categorical_accuracy: 0.9056 - mean_dice_coef: 0.7360 - weighted_mean_dice_coef: 0.6475 - val_loss: 0.3252 - val_categorical_accuracy: 0.8957 - val_mean_dice_coef: 0.7530 - val_weighted_mean_dice_coef: 0.6748 - lr: 0.0010
# Epoch 37/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3518 - categorical_accuracy: 0.9058 - mean_dice_coef: 0.7365 - weighted_mean_dice_coef: 0.6482 - val_loss: 0.3284 - val_categorical_accuracy: 0.8963 - val_mean_dice_coef: 0.7517 - val_weighted_mean_dice_coef: 0.6716 - lr: 0.0010
# Epoch 38/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3517 - categorical_accuracy: 0.9059 - mean_dice_coef: 0.7366 - weighted_mean_dice_coef: 0.6483 - val_loss: 0.3243 - val_categorical_accuracy: 0.8941 - val_mean_dice_coef: 0.7531 - val_weighted_mean_dice_coef: 0.6757 - lr: 0.0010
# Epoch 39/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3513 - categorical_accuracy: 0.9059 - mean_dice_coef: 0.7369 - weighted_mean_dice_coef: 0.6487 - val_loss: 0.3413 - val_categorical_accuracy: 0.9001 - val_mean_dice_coef: 0.7414 - val_weighted_mean_dice_coef: 0.6587 - lr: 0.0010
# Epoch 40/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3508 - categorical_accuracy: 0.9061 - mean_dice_coef: 0.7373 - weighted_mean_dice_coef: 0.6492 - val_loss: 0.3362 - val_categorical_accuracy: 0.8968 - val_mean_dice_coef: 0.7468 - val_weighted_mean_dice_coef: 0.6638 - lr: 0.0010
# Epoch 41/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3505 - categorical_accuracy: 0.9063 - mean_dice_coef: 0.7376 - weighted_mean_dice_coef: 0.6495 - val_loss: 0.3203 - val_categorical_accuracy: 0.8967 - val_mean_dice_coef: 0.7565 - val_weighted_mean_dice_coef: 0.6797 - lr: 0.0010
# Epoch 42/60
# 995/995 [==============================] - 101s 101ms/step - loss: 0.3516 - categorical_accuracy: 0.9059 - mean_dice_coef: 0.7366 - weighted_mean_dice_coef: 0.6484 - val_loss: 0.3453 - val_categorical_accuracy: 0.8905 - val_mean_dice_coef: 0.7376 - val_weighted_mean_dice_coef: 0.6547 - lr: 0.0010
# Epoch 43/60
# 995/995 [==============================] - 100s 100ms/step - loss: 0.3505 - categorical_accuracy: 0.9062 - mean_dice_coef: 0.7375 - weighted_mean_dice_coef: 0.6495 - val_loss: 0.3496 - val_categorical_accuracy: 0.8969 - val_mean_dice_coef: 0.7384 - val_weighted_mean_dice_coef: 0.6504 - lr: 0.0010
# Epoch 44/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3496 - categorical_accuracy: 0.9067 - mean_dice_coef: 0.7382 - weighted_mean_dice_coef: 0.6504 - val_loss: 0.3168 - val_categorical_accuracy: 0.8951 - val_mean_dice_coef: 0.7584 - val_weighted_mean_dice_coef: 0.6832 - lr: 0.0010
# Epoch 45/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3497 - categorical_accuracy: 0.9064 - mean_dice_coef: 0.7382 - weighted_mean_dice_coef: 0.6503 - val_loss: 0.3638 - val_categorical_accuracy: 0.8918 - val_mean_dice_coef: 0.7282 - val_weighted_mean_dice_coef: 0.6362 - lr: 0.0010
# Epoch 46/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3496 - categorical_accuracy: 0.9065 - mean_dice_coef: 0.7382 - weighted_mean_dice_coef: 0.6504 - val_loss: 0.3146 - val_categorical_accuracy: 0.8940 - val_mean_dice_coef: 0.7598 - val_weighted_mean_dice_coef: 0.6854 - lr: 0.0010
# Epoch 47/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3488 - categorical_accuracy: 0.9067 - mean_dice_coef: 0.7388 - weighted_mean_dice_coef: 0.6512 - val_loss: 0.3431 - val_categorical_accuracy: 0.9002 - val_mean_dice_coef: 0.7405 - val_weighted_mean_dice_coef: 0.6569 - lr: 0.0010
# Epoch 48/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3487 - categorical_accuracy: 0.9066 - mean_dice_coef: 0.7389 - weighted_mean_dice_coef: 0.6513 - val_loss: 0.3184 - val_categorical_accuracy: 0.8976 - val_mean_dice_coef: 0.7584 - val_weighted_mean_dice_coef: 0.6816 - lr: 0.0010
# Epoch 49/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3487 - categorical_accuracy: 0.9067 - mean_dice_coef: 0.7389 - weighted_mean_dice_coef: 0.6513 - val_loss: 0.3207 - val_categorical_accuracy: 0.8971 - val_mean_dice_coef: 0.7565 - val_weighted_mean_dice_coef: 0.6793 - lr: 0.0010
# Epoch 50/60
# 995/995 [==============================] - 101s 102ms/step - loss: 0.3484 - categorical_accuracy: 0.9066 - mean_dice_coef: 0.7391 - weighted_mean_dice_coef: 0.6516 - val_loss: 0.3162 - val_categorical_accuracy: 0.8958 - val_mean_dice_coef: 0.7588 - val_weighted_mean_dice_coef: 0.6838 - lr: 0.0010
# Epoch 51/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3482 - categorical_accuracy: 0.9068 - mean_dice_coef: 0.7392 - weighted_mean_dice_coef: 0.6518 - val_loss: 0.3357 - val_categorical_accuracy: 0.9001 - val_mean_dice_coef: 0.7474 - val_weighted_mean_dice_coef: 0.6643 - lr: 0.0010
# Epoch 52/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3482 - categorical_accuracy: 0.9069 - mean_dice_coef: 0.7393 - weighted_mean_dice_coef: 0.6518 - val_loss: 0.3277 - val_categorical_accuracy: 0.8995 - val_mean_dice_coef: 0.7521 - val_weighted_mean_dice_coef: 0.6723 - lr: 0.0010
# Epoch 53/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3477 - categorical_accuracy: 0.9070 - mean_dice_coef: 0.7396 - weighted_mean_dice_coef: 0.6523 - val_loss: 0.3224 - val_categorical_accuracy: 0.8999 - val_mean_dice_coef: 0.7553 - val_weighted_mean_dice_coef: 0.6776 - lr: 0.0010
# Epoch 54/60
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3482 - categorical_accuracy: 0.9068 - mean_dice_coef: 0.7393 - weighted_mean_dice_coef: 0.6518 - val_loss: 0.3279 - val_categorical_accuracy: 0.8879 - val_mean_dice_coef: 0.7492 - val_weighted_mean_dice_coef: 0.6721 - lr: 0.0010
# Epoch 55/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3474 - categorical_accuracy: 0.9069 - mean_dice_coef: 0.7399 - weighted_mean_dice_coef: 0.6526 - val_loss: 0.3279 - val_categorical_accuracy: 0.9012 - val_mean_dice_coef: 0.7516 - val_weighted_mean_dice_coef: 0.6721 - lr: 0.0010
# Epoch 56/60
# 995/995 [==============================] - ETA: 0s - loss: 0.3478 - categorical_accuracy: 0.9069 - mean_dice_coef: 0.7395 - weighted_mean_dice_coef: 0.6522
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 995/995 [==============================] - 102s 102ms/step - loss: 0.3478 - categorical_accuracy: 0.9069 - mean_dice_coef: 0.7395 - weighted_mean_dice_coef: 0.6522 - val_loss: 0.3375 - val_categorical_accuracy: 0.8958 - val_mean_dice_coef: 0.7431 - val_weighted_mean_dice_coef: 0.6625 - lr: 0.0010
# Epoch 57/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3438 - categorical_accuracy: 0.9080 - mean_dice_coef: 0.7425 - weighted_mean_dice_coef: 0.6562 - val_loss: 0.3286 - val_categorical_accuracy: 0.9005 - val_mean_dice_coef: 0.7515 - val_weighted_mean_dice_coef: 0.6714 - lr: 5.0000e-04
# Epoch 58/60
# 995/995 [==============================] - 103s 103ms/step - loss: 0.3432 - categorical_accuracy: 0.9082 - mean_dice_coef: 0.7430 - weighted_mean_dice_coef: 0.6568 - val_loss: 0.3213 - val_categorical_accuracy: 0.8949 - val_mean_dice_coef: 0.7558 - val_weighted_mean_dice_coef: 0.6787 - lr: 5.0000e-04
# Epoch 59/60
# 995/995 [==============================] - 101s 102ms/step - loss: 0.3434 - categorical_accuracy: 0.9081 - mean_dice_coef: 0.7428 - weighted_mean_dice_coef: 0.6566 - val_loss: 0.3177 - val_categorical_accuracy: 0.8906 - val_mean_dice_coef: 0.7570 - val_weighted_mean_dice_coef: 0.6823 - lr: 5.0000e-04
# Epoch 60/60
# 995/995 [==============================] - 102s 103ms/step - loss: 0.3431 - categorical_accuracy: 0.9081 - mean_dice_coef: 0.7431 - weighted_mean_dice_coef: 0.6569 - val_loss: 0.3208 - val_categorical_accuracy: 0.8997 - val_mean_dice_coef: 0.7571 - val_weighted_mean_dice_coef: 0.6792 - lr: 5.0000e-04

# %%
model.save_weights(file_path_save + '/weights.h5')

# %%
dir_path = "/albedo/work/user/ssunar/for_paper/unet_trained/Gulfstream/"
plt.figure(figsize=(10, 10))
plt.semilogy(model.history.history['loss'])
plt.semilogy(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss', 'val_loss'], loc='upper right');
plt.savefig(dir_path + "loss_graph.png", dpi = 300)
# Out:
# Text(0.5, 1.0, 'model loss')
# Text(0, 0.5, 'loss')
# Text(0.5, 0, 'epoch')

# %%
import time
from sklearn.metrics import classification_report
start = time.time()
val_gen = plain_net_eddy(batch_size, img_size, val_input, val_target)
val_preds = model.predict(val_gen)
print(val_preds.shape)

end = time.time()
time_per_img = (end - start)/val_preds.shape[0]
print("Time Per image:",time_per_img)
print("Time for 1 year eqv:",time_per_img*365)
# Out:
# 426/426 [==============================] - 8s 18ms/step
# (6816, 65536, 3)
# Time Per image: 0.0014822306767315933
# Time for 1 year eqv: 0.5410141970070316

# %%
# Since we do not use all samples for training.
if len(data_x) > total_samples + 1000:
    test_size = 1000
    test_inp = data_x[total_samples : total_samples+test_size]
    test_seg = data_y[total_samples : total_samples+test_size]
elif len(data_x) > total_samples:
    test_size = len(data_x) - total_samples
    test_inp = data_x[total_samples : total_samples+test_size]
    test_seg = data_y[total_samples : total_samples+test_size]
else:
    test_inp = val_input
    test_seg = val_target
    test_size = len(test_inp)
    
test_inp.shape
test_seg.shape
# Out:
# (1000, 256, 256)
# (1000, 256, 256)

# %%
# convert test segmentation mask into catagorical form
categorical_test_seg = to_categorical(test_seg)
categorical_test_seg.shape
# Out:
# (1000, 256, 256, 3)

# %%
# Prediction on test data
test_inp = np.reshape(test_inp,(len(test_inp),img_size[0],img_size[1],1))
catagorical_test_preds = model.predict(test_inp)
# Out:
# 32/32 [==============================] - 1s 15ms/step

# %%
model.evaluate(test_inp, catagorical_test_preds)
# Out:
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0023 - categorical_accuracy: 1.0000 - mean_dice_coef: 0.9983 - weighted_mean_dice_coef: 0.9977
# [0.002276031067594886, 1.0, 0.9982935786247253, 0.9977260828018188]

# %%
mask = np.argmax(np.reshape(catagorical_test_preds[70],(1,img_size[1],img_size[0],3)), axis=-1)
mask = np.reshape(mask,(img_size[0],img_size[1]))

# %%
#seeing the prediction of one image of the validation set
# %matplotlib inline

plt.figure(figsize=(20, 10))

plt.subplot(131)
plt.imshow(mask.T, cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.axis('off')
plt.title('Result Segmentation');
plt.savefig(dir_path + "prediction.png", dpi = 300)

plt.subplot(132)
plt.imshow(test_seg[70].T, cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.axis('off')
plt.title('Groundtruth Segmentation');
plt.savefig(dir_path + "groundtruth.png", dpi = 300)
# Out:
# <AxesSubplot:>
# (-0.5, 255.5, 255.5, -0.5)
# Text(0.5, 1.0, 'Result Segmentation')
# <AxesSubplot:>
# (-0.5, 255.5, 255.5, -0.5)
# Text(0.5, 1.0, 'Groundtruth Segmentation')
